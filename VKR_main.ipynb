# %% [markdown]
# # Импорт библиотек и датасетов

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn as skl

# %% [markdown]
# Загружаем датасеты, используя функцию read, параметром index_col исключаем создание дополнительного столбца в качестве индексного:

# %%
df_1=pd.read_excel('data/X_bp.xlsx', index_col=0)
df_2=pd.read_excel('data/X_nup.xlsx', index_col=0)

# %%
df_1.head(3)
# Out:
#     Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# No
# 0                          1.857143            2030.0             738.736842
# 1                          1.857143            2030.0             738.736842
# 2                          1.857143            2030.0             738.736842
#
#     Количество отвердителя, м.%  Содержание эпоксидных групп,%_2  \
# No
# 0                          30.0                        22.267857
# 1                          50.0                        23.750000
# 2                          49.9                        33.000000
#
#     Температура вспышки, С_2  Поверхностная плотность, г/м2  \
# No
# 0                 100.000000                          210.0
# 1                 284.615385                          210.0
# 2                 284.615385                          210.0
#
#     Модуль упругости при растяжении, ГПа  Прочность при растяжении, МПа  \
# No
# ...

# %%
df_1.tail(3)
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# No
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# No
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# No
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# No
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# ...

# %%
df_2.tail(3)
# Out:
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# No
# 1037                  90     9.800926          72.858286
# 1038                  90    10.079859          65.519479
# 1039                  90     9.021043          66.920143

# %% [markdown]
# Датасет 1 (X_bp.xlsx) имеет 1023 строки записей, датасет 2 (X_nup.xlsx) - 1040 строк. Поскольку ДС1 имеет значительно больше данных (столбцов), пытаться заполнить/предсказать пропуски при объединении бессмысленно, кроме прочего 15 строк это не более 1,5% всех данных. Таким образом, пренебрегаем "лишними" строками второго датасета, объединенный датасет будет иметь 1023 строки.

# %%
df=df_1.merge(df_2, left_index=True, right_index=True, how='inner')
df
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# No
# 0                            1.857143       2030.000000
# 1                            1.857143       2030.000000
# 2                            1.857143       2030.000000
# 3                            1.857143       2030.000000
# 4                            2.771331       2030.000000
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# No
# 0                738.736842                    30.000000
# 1                738.736842                    50.000000
# 2                738.736842                    49.900000
# ...

# %%
df.describe().T
# Out:
#                                        count         mean         std  \
# Соотношение матрица-наполнитель       1023.0     2.930366    0.913222
# Плотность, кг/м3                      1023.0  1975.734888   73.729231
# модуль упругости, ГПа                 1023.0   739.923233  330.231581
# Количество отвердителя, м.%           1023.0   110.570769   28.295911
# Содержание эпоксидных групп,%_2       1023.0    22.244390    2.406301
# Температура вспышки, С_2              1023.0   285.882151   40.943260
# Поверхностная плотность, г/м2         1023.0   482.731833  281.314690
# Модуль упругости при растяжении, ГПа  1023.0    73.328571    3.118983
# Прочность при растяжении, МПа         1023.0  2466.922843  485.628006
# Потребление смолы, г/м2               1023.0   218.423144   59.735931
# Угол нашивки, град                    1023.0    44.252199   45.015793
# Шаг нашивки                           1023.0     6.899222    2.563467
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1023 non-null   float64
#  1   Плотность, кг/м3                      1023 non-null   float64
#  2   модуль упругости, ГПа                 1023 non-null   float64
#  3   Количество отвердителя, м.%           1023 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1023 non-null   float64
#  5   Температура вспышки, С_2              1023 non-null   float64
#  6   Поверхностная плотность, г/м2         1023 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1023 non-null   float64
#  8   Прочность при растяжении, МПа         1023 non-null   float64
#  9   Потребление смолы, г/м2               1023 non-null   float64
# ...

# %% [markdown]
# Из результатов, полученных методом .info (выше), видно, что все 1023 строки каждого столбца имеют не нулевое значение, также проверку можно произвести  методом .isnull:

# %%
df.isnull().sum()
# Out:
# Соотношение матрица-наполнитель         0
# Плотность, кг/м3                        0
# модуль упругости, ГПа                   0
# Количество отвердителя, м.%             0
# Содержание эпоксидных групп,%_2         0
# Температура вспышки, С_2                0
# Поверхностная плотность, г/м2           0
# Модуль упругости при растяжении, ГПа    0
# Прочность при растяжении, МПа           0
# Потребление смолы, г/м2                 0
# Угол нашивки, град                      0
# Шаг нашивки                             0
# Плотность нашивки                       0
# dtype: int64

# %% [markdown]
# Аналогично датасет проверяется на пропуски:

# %%
df.isna().sum()
# Out:
# Соотношение матрица-наполнитель         0
# Плотность, кг/м3                        0
# модуль упругости, ГПа                   0
# Количество отвердителя, м.%             0
# Содержание эпоксидных групп,%_2         0
# Температура вспышки, С_2                0
# Поверхностная плотность, г/м2           0
# Модуль упругости при растяжении, ГПа    0
# Прочность при растяжении, МПа           0
# Потребление смолы, г/м2                 0
# Угол нашивки, град                      0
# Шаг нашивки                             0
# Плотность нашивки                       0
# dtype: int64

# %% [markdown]
# # Визуализация исходных данных:

# %%
df.columns
# Out:
# Index(['Соотношение матрица-наполнитель', 'Плотность, кг/м3',
#        'модуль упругости, ГПа', 'Количество отвердителя, м.%',
#        'Содержание эпоксидных групп,%_2', 'Температура вспышки, С_2',
#        'Поверхностная плотность, г/м2', 'Модуль упругости при растяжении, ГПа',
#        'Прочность при растяжении, МПа', 'Потребление смолы, г/м2',
#        'Угол нашивки, град', 'Шаг нашивки', 'Плотность нашивки'],
#       dtype='object')

# %% [markdown]
# Гистограммы распределения:

# %%
for x in df.columns:
    plt.figure(figsize=(6, 3))
    sns.histplot(data=df[x])
    plt.show
